# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# ### Results - Observations:
#
#     The Latitude vs. Temperature Plot,  visually validates that closer to Equator (0degree Lat) it gets warmer with most cities being within -25 to 25 degrees Latitude. Also they change depending on the time of the day.
#
#     Also reflects no strong relationship between Lat and Humidity, though it appears to be more humid as you are in the S. Hemishpere (0 to 30/40 deg. Lat)
#     Latitude and Cloudiness reflect very little relationship, though interesting there appears to be standardization of results as we see many groupings
#
#     Latitude and wind reflect very little relationship, though it appears that more towards the S. Hempishphere its more windy based on the number of cities in this region relative to N.Hempisphere.

# %%
# Dependencies and Setup

import csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests 
import time 
import openweathermapy.core as owm
from datetime import datetime

# API key - note needed account to be created (free)
from api_keys import api_key

#note need to install citipy 
#pip install citipy

# Additional imports - city information (provided)
## Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Refer link below for details on using openweathermapy.core python utility
#https://github.com/crazycapivara/openweathermapy


# Output File (CSV)
#
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

current_time = datetime.now()
current_date = current_time.strftime('%m/%d/%Y')

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []


# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)


# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Refer usage example 
#settings = {"units": "metric", "lang": "DE"}
#>>> data = owm.get_current("Kassel,DE", **settings)
# settings containing APIKEY
#>>> settings = {"APPID": 1111111111, "units": "metric"}

# Refer link to formt and extract weather data 
# https://github.com/crazycapivara/openweathermapy

# example to select weather info from API 
# https://samples.openweathermap.org/data/2.5/weather?lat=35&lon=139&appid=b6907d289e10d714a6e88b30761fae22


# List to hold city weather information 

city_weather = []

x = 1
set = 1

settings = {'units':'imperial', 'appid':api_key}


for city in cities:
    
    try:
        data = owm.get_current(city, **settings)     
        
      

        city_weather.append({ 
        'City'       :  data['name'],
        'Cloudiness' : data['clouds']['all'],
        'Country'    : data['sys']['country'],
        'Date'       : data['dt'],
        'Humidity'   : data['main']['humidity'],
        'Lat'        : data['coord']['lat'],
        'Lng'        : data['coord']['lon'],
        'Max_Temp'   : data['main']['temp_max'],
        'Wind_Speed' : data['wind'] ['speed']
                        })
        print(f"Processing Record {x} of Set {set} |  {city}")
    
    except:
        print("Missing City....skipping")   
        x = 0
        set = set + 1

    x = x + 1
                                             
print(' Extraction Complelte')
# Out:
# Processing Record 1 of Set 1 |  upernavik
# Processing Record 2 of Set 1 |  lavrentiya
# Missing City....skipping
# Processing Record 1 of Set 2 |  ushuaia
# Processing Record 2 of Set 2 |  sitka
# Processing Record 3 of Set 2 |  ponta do sol
# Missing City....skipping
# Missing City....skipping
# Processing Record 1 of Set 4 |  lucapa
# Missing City....skipping
# Processing Record 1 of Set 5 |  busselton
# Missing City....skipping
# Processing Record 1 of Set 6 |  airai
# Processing Record 2 of Set 6 |  atuona
# Missing City....skipping
# Processing Record 1 of Set 7 |  zambezi
# Processing Record 2 of Set 7 |  saint-philippe
# Processing Record 3 of Set 7 |  thompson
# Processing Record 4 of Set 7 |  vardo
# Processing Record 5 of Set 7 |  slobodskoy
# Processing Record 6 of Set 7 |  bluff
# Processing Record 7 of Set 7 |  tibati
# Processing Record 8 of Set 7 |  punta arenas
# Processing Record 9 of Set 7 |  nelson bay
# Processing Record 10 of Set 7 |  luderitz
# Processing Record 11 of Set 7 |  bichura
# Processing Record 12 of Set 7 |  ust-kuyga
# Processing Record 13 of Set 7 |  albany
# Processing Record 14 of Set 7 |  amazar
# Processing Record 15 of Set 7 |  fernley
# Processing Record 16 of Set 7 |  logan lake
# Processing Record 17 of Set 7 |  vaini
# Processing Record 18 of Set 7 |  kysyl-syr
# Processing Record 19 of Set 7 |  bethel
# Processing Record 20 of Set 7 |  faanui
# Processing Record 21 of Set 7 |  rikitea
# Processing Record 22 of Set 7 |  thiruvananthapuram
# Processing Record 23 of Set 7 |  burgersdorp
# Processing Record 24 of Set 7 |  saskylakh
# Processing Record 25 of Set 7 |  sterling
# Processing Record 26 of Set 7 |  hobart
# Processing Record 27 of Set 7 |  kapaa
# Processing Record 28 of Set 7 |  constitucion
# Processing Record 29 of Set 7 |  hilo
# Missing City....skipping
# Processing Record 1 of Set 8 |  petrov val
# Processing Record 2 of Set 8 |  hermanus
# Processing Record 3 of Set 8 |  dikson
# Processing Record 4 of Set 8 |  aklavik
# Processing Record 5 of Set 8 |  ayutla
# Processing Record 6 of Set 8 |  lasa
# Processing Record 7 of Set 8 |  tautira
# Processing Record 8 of Set 8 |  port elizabeth
# Processing Record 9 of Set 8 |  dong hoi
# Processing Record 10 of Set 8 |  ribeira grande
# Processing Record 11 of Set 8 |  carnarvon
# Processing Record 12 of Set 8 |  lompoc
# Processing Record 13 of Set 8 |  pauini
# Processing Record 14 of Set 8 |  erzin
# Processing Record 15 of Set 8 |  sao joao da barra
# Processing Record 16 of Set 8 |  mataura
# Processing Record 17 of Set 8 |  khatanga
# Missing City....skipping
# Processing Record 1 of Set 9 |  mar del plata
# Missing City....skipping
# Processing Record 1 of Set 10 |  goderich
# Missing City....skipping
# Processing Record 1 of Set 11 |  mezen
# Processing Record 2 of Set 11 |  barrow
# Processing Record 3 of Set 11 |  jamestown
# Processing Record 4 of Set 11 |  pacific grove
# Processing Record 5 of Set 11 |  gannan
# Processing Record 6 of Set 11 |  avarua
# Processing Record 7 of Set 11 |  north bend
# Processing Record 8 of Set 11 |  narsaq
# Missing City....skipping
# Processing Record 1 of Set 12 |  tiksi
# Processing Record 2 of Set 12 |  camargo
# Processing Record 3 of Set 12 |  saint george
# Processing Record 4 of Set 12 |  port alfred
# Missing City....skipping
# Processing Record 1 of Set 13 |  yerbogachen
# Processing Record 2 of Set 13 |  barbalha
# Processing Record 3 of Set 13 |  diffa
# Processing Record 4 of Set 13 |  hambantota
# Processing Record 5 of Set 13 |  eureka
# Processing Record 6 of Set 13 |  kimbe
# Processing Record 7 of Set 13 |  santo antonio de padua
# Processing Record 8 of Set 13 |  lebu
# Processing Record 9 of Set 13 |  chokurdakh
# Processing Record 10 of Set 13 |  bahia blanca
# Processing Record 11 of Set 13 |  fort nelson
# Processing Record 12 of Set 13 |  iquique
# Processing Record 13 of Set 13 |  paamiut
# Processing Record 14 of Set 13 |  ambon
# Processing Record 15 of Set 13 |  gbarnga
# Missing City....skipping
# Processing Record 1 of Set 14 |  puerto suarez
# Processing Record 2 of Set 14 |  kodiak
# Processing Record 3 of Set 14 |  puerto escondido
# Processing Record 4 of Set 14 |  bredasdorp
# Processing Record 5 of Set 14 |  leopoldov
# Processing Record 6 of Set 14 |  vestmannaeyjar
# Processing Record 7 of Set 14 |  longyearbyen
# Processing Record 8 of Set 14 |  qaanaaq
# Processing Record 9 of Set 14 |  rognan
# Processing Record 10 of Set 14 |  georgetown
# Processing Record 11 of Set 14 |  katsuura
# Processing Record 12 of Set 14 |  san rafael
# Processing Record 13 of Set 14 |  boa esperanca
# Processing Record 14 of Set 14 |  nome
# Missing City....skipping
# Processing Record 1 of Set 15 |  nikolskoye
# Processing Record 2 of Set 15 |  tasiilaq
# Processing Record 3 of Set 15 |  namatanai
# Processing Record 4 of Set 15 |  sao filipe
# Processing Record 5 of Set 15 |  zhigansk
# Processing Record 6 of Set 15 |  noumea
# Processing Record 7 of Set 15 |  mahenge
# Processing Record 8 of Set 15 |  dingle
# Missing City....skipping
# Processing Record 1 of Set 16 |  coihaique
# Processing Record 2 of Set 16 |  riofrio
# Processing Record 3 of Set 16 |  sola
# Processing Record 4 of Set 16 |  berlevag
# Processing Record 5 of Set 16 |  caramay
# Processing Record 6 of Set 16 |  iqaluit
# Processing Record 7 of Set 16 |  alofi
# Missing City....skipping
# Missing City....skipping
# Missing City....skipping
# Processing Record 1 of Set 19 |  puerto ayora
# Missing City....skipping
# Missing City....skipping
# Processing Record 1 of Set 21 |  cabo san lucas
# Processing Record 2 of Set 21 |  cayenne
# Processing Record 3 of Set 21 |  cacoal
# Processing Record 4 of Set 21 |  wasilla
# Processing Record 5 of Set 21 |  almaznyy
# Processing Record 6 of Set 21 |  shelburne
# Processing Record 7 of Set 21 |  hofn
# Processing Record 8 of Set 21 |  lamar
# Processing Record 9 of Set 21 |  prince george
# Processing Record 10 of Set 21 |  dunedin
# Missing City....skipping
# Processing Record 1 of Set 22 |  jega
# Processing Record 2 of Set 22 |  san patricio
# Processing Record 3 of Set 22 |  chuy
# Processing Record 4 of Set 22 |  new norfolk
# Processing Record 5 of Set 22 |  hamilton
# Processing Record 6 of Set 22 |  hami
# Processing Record 7 of Set 22 |  houma
# Processing Record 8 of Set 22 |  yellowknife
# Processing Record 9 of Set 22 |  lokoja
# Processing Record 10 of Set 22 |  mahebourg
# Processing Record 11 of Set 22 |  moranbah
# Processing Record 12 of Set 22 |  mount isa
# Processing Record 13 of Set 22 |  margate
# Processing Record 14 of Set 22 |  mathbaria
# Processing Record 15 of Set 22 |  portland
# Processing Record 16 of Set 22 |  kavieng
# Processing Record 17 of Set 22 |  tuatapere
# Processing Record 18 of Set 22 |  coquimbo
# Processing Record 19 of Set 22 |  kathu
# Processing Record 20 of Set 22 |  mahibadhoo
# Processing Record 21 of Set 22 |  bilma
# Processing Record 22 of Set 22 |  kavaratti
# Processing Record 23 of Set 22 |  marsa matruh
# Processing Record 24 of Set 22 |  tandalti
# Processing Record 25 of Set 22 |  lipin bor
# Processing Record 26 of Set 22 |  joinville
# Processing Record 27 of Set 22 |  minsk
# Processing Record 28 of Set 22 |  tessalit
# Processing Record 29 of Set 22 |  winnemucca
# Processing Record 30 of Set 22 |  the pas
# Processing Record 31 of Set 22 |  nouadhibou
# Processing Record 32 of Set 22 |  sedalia
# Processing Record 33 of Set 22 |  merauke
# Processing Record 34 of Set 22 |  torbay
# Processing Record 35 of Set 22 |  petukhovo
# Missing City....skipping
# Missing City....skipping
# Processing Record 1 of Set 24 |  orlik
# Processing Record 2 of Set 24 |  tynda
# Processing Record 3 of Set 24 |  butaritari
# Processing Record 4 of Set 24 |  ozernovskiy
# Processing Record 5 of Set 24 |  chamba
# Processing Record 6 of Set 24 |  boffa
# Processing Record 7 of Set 24 |  mutoko
# Processing Record 8 of Set 24 |  mayen
# Missing City....skipping
# Processing Record 1 of Set 25 |  preobrazheniye
# Processing Record 2 of Set 25 |  cape town
# Processing Record 3 of Set 25 |  tilichiki
# Processing Record 4 of Set 25 |  half moon bay
# Processing Record 5 of Set 25 |  teguldet
# Processing Record 6 of Set 25 |  lorengau
# Processing Record 7 of Set 25 |  kulgam
# Processing Record 8 of Set 25 |  kahului
# Processing Record 9 of Set 25 |  timizart
# Processing Record 10 of Set 25 |  gashua
# Missing City....skipping
# Processing Record 1 of Set 26 |  utete
# Processing Record 2 of Set 26 |  buin
# Processing Record 3 of Set 26 |  fortuna
# Missing City....skipping
# Processing Record 1 of Set 27 |  huarmey
# Processing Record 2 of Set 27 |  kumba
# Processing Record 3 of Set 27 |  port lincoln
# Processing Record 4 of Set 27 |  shakawe
# Processing Record 5 of Set 27 |  havoysund
# Processing Record 6 of Set 27 |  port moresby
# Processing Record 7 of Set 27 |  esperance
# Processing Record 8 of Set 27 |  porto nacional
# Processing Record 9 of Set 27 |  vostok
# Processing Record 10 of Set 27 |  quatre cocos
# Processing Record 11 of Set 27 |  saldanha
# Processing Record 12 of Set 27 |  coahuayana
# Processing Record 13 of Set 27 |  castro
# Processing Record 14 of Set 27 |  narang
# Processing Record 15 of Set 27 |  nanortalik
# Processing Record 16 of Set 27 |  tateyama
# Processing Record 17 of Set 27 |  shimanovsk
# Processing Record 18 of Set 27 |  klyuchi
# Processing Record 19 of Set 27 |  canning
# Processing Record 20 of Set 27 |  kaitangata
# Processing Record 21 of Set 27 |  soubre
# Processing Record 22 of Set 27 |  husavik
# Processing Record 23 of Set 27 |  bambous virieux
# Processing Record 24 of Set 27 |  sorland
# Processing Record 25 of Set 27 |  santa vitoria do palmar
# Missing City....skipping
# Processing Record 1 of Set 28 |  nuuk
# Processing Record 2 of Set 28 |  sistranda
# Processing Record 3 of Set 28 |  tongliao
# Processing Record 4 of Set 28 |  viedma
# Processing Record 5 of Set 28 |  auki
# Processing Record 6 of Set 28 |  santiago de cuba
# Processing Record 7 of Set 28 |  laguna
# Processing Record 8 of Set 28 |  tuktoyaktuk
# Processing Record 9 of Set 28 |  djibo
# Processing Record 10 of Set 28 |  balabac
# Processing Record 11 of Set 28 |  bari sadri
# Processing Record 12 of Set 28 |  soto la marina
# Processing Record 13 of Set 28 |  san rafael del sur
# Processing Record 14 of Set 28 |  pangnirtung
# Processing Record 15 of Set 28 |  savinka
# Processing Record 16 of Set 28 |  saint-joseph
# Processing Record 17 of Set 28 |  chapais
# Processing Record 18 of Set 28 |  le port
# Processing Record 19 of Set 28 |  terrace
# Processing Record 20 of Set 28 |  haines junction
# Processing Record 21 of Set 28 |  tombouctou
# Processing Record 22 of Set 28 |  porto novo
# Processing Record 23 of Set 28 |  palmares do sul
# Processing Record 24 of Set 28 |  provideniya
# Processing Record 25 of Set 28 |  hithadhoo
# Processing Record 26 of Set 28 |  gwadar
# Processing Record 27 of Set 28 |  buraydah
# Processing Record 28 of Set 28 |  lagunas
# Missing City....skipping
# Processing Record 1 of Set 29 |  hirara
# Processing Record 2 of Set 29 |  pahalgam
# Processing Record 3 of Set 29 |  acapulco
# Missing City....skipping
# Processing Record 1 of Set 30 |  nantucket
# Processing Record 2 of Set 30 |  caravelas
# Processing Record 3 of Set 30 |  richards bay
# Processing Record 4 of Set 30 |  bay roberts
# Processing Record 5 of Set 30 |  cherskiy
# Processing Record 6 of Set 30 |  kruisfontein
# Missing City....skipping
# Processing Record 1 of Set 31 |  kamaishi
# Missing City....skipping
# Processing Record 1 of Set 32 |  pochutla
# Processing Record 2 of Set 32 |  vestmanna
# Processing Record 3 of Set 32 |  ilulissat
# Processing Record 4 of Set 32 |  xining
# Processing Record 5 of Set 32 |  plettenberg bay
# Processing Record 6 of Set 32 |  hoquiam
# Processing Record 7 of Set 32 |  kupang
# Missing City....skipping
# Missing City....skipping
# Processing Record 1 of Set 34 |  guerrero negro
# Processing Record 2 of Set 34 |  amapa
# Processing Record 3 of Set 34 |  altay
# Processing Record 4 of Set 34 |  rio gallegos
# Processing Record 5 of Set 34 |  east london
# Processing Record 6 of Set 34 |  pevek
# Processing Record 7 of Set 34 |  padang
# Processing Record 8 of Set 34 |  port blair
# Processing Record 9 of Set 34 |  abha
# Processing Record 10 of Set 34 |  cidreira
# Processing Record 11 of Set 34 |  bobon
# Processing Record 12 of Set 34 |  karratha
# Missing City....skipping
# Processing Record 1 of Set 35 |  nemuro
# Processing Record 2 of Set 35 |  tulcea
# Processing Record 3 of Set 35 |  singaraja
# Processing Record 4 of Set 35 |  nuevo progreso
# Missing City....skipping
# Processing Record 1 of Set 36 |  necochea
# Processing Record 2 of Set 36 |  berkakit
# Processing Record 3 of Set 36 |  makakilo city
# Processing Record 4 of Set 36 |  norman wells
# Processing Record 5 of Set 36 |  tiznit
# Processing Record 6 of Set 36 |  grand gaube
# Processing Record 7 of Set 36 |  roald
# Processing Record 8 of Set 36 |  penzance
# Processing Record 9 of Set 36 |  lata
# Processing Record 10 of Set 36 |  uglegorsk
# Processing Record 11 of Set 36 |  san pedro de macoris
# Processing Record 12 of Set 36 |  pitimbu
# Missing City....skipping
# Processing Record 1 of Set 37 |  bazpur
# Processing Record 2 of Set 37 |  vila velha
# Processing Record 3 of Set 37 |  otavi
# Processing Record 4 of Set 37 |  san roque
# Processing Record 5 of Set 37 |  pilar de la horadada
# Processing Record 6 of Set 37 |  adrar
# Processing Record 7 of Set 37 |  matara
# Processing Record 8 of Set 37 |  chipinge
# Processing Record 9 of Set 37 |  flinders
# Processing Record 10 of Set 37 |  bonthe
# Processing Record 11 of Set 37 |  sanmenxia
# Processing Record 12 of Set 37 |  bukoba
# Processing Record 13 of Set 37 |  dordrecht
# Processing Record 14 of Set 37 |  killybegs
# Processing Record 15 of Set 37 |  sycamore
# Processing Record 16 of Set 37 |  namibe
# Processing Record 17 of Set 37 |  faya
# Processing Record 18 of Set 37 |  hasaki
# Processing Record 19 of Set 37 |  naze
# Processing Record 20 of Set 37 |  bilibino
# Processing Record 21 of Set 37 |  kinwat
# Processing Record 22 of Set 37 |  primo tapia
# Processing Record 23 of Set 37 |  shediac
# Processing Record 24 of Set 37 |  leh
# Missing City....skipping
# Processing Record 1 of Set 38 |  srednekolymsk
# Processing Record 2 of Set 38 |  poole
# Processing Record 3 of Set 38 |  kirakira
# Processing Record 4 of Set 38 |  kampot
# Processing Record 5 of Set 38 |  taltal
# Processing Record 6 of Set 38 |  alice springs
# Processing Record 7 of Set 38 |  maniitsoq
# Processing Record 8 of Set 38 |  bure
# Missing City....skipping
# Processing Record 1 of Set 39 |  aswan
# Processing Record 2 of Set 39 |  nishihara
# Processing Record 3 of Set 39 |  cockburn town
# Processing Record 4 of Set 39 |  west wendover
# Processing Record 5 of Set 39 |  souillac
# Processing Record 6 of Set 39 |  honningsvag
# Missing City....skipping
# Processing Record 1 of Set 40 |  marawi
# Processing Record 2 of Set 40 |  puerto madryn
# Processing Record 3 of Set 40 |  zeerust
# Processing Record 4 of Set 40 |  mujiayingzi
# Processing Record 5 of Set 40 |  montes altos
# Processing Record 6 of Set 40 |  igunga
# Processing Record 7 of Set 40 |  magistralnyy
# Processing Record 8 of Set 40 |  mandalgovi
# Processing Record 9 of Set 40 |  arraial do cabo
# Processing Record 10 of Set 40 |  ballina
# Missing City....skipping
# Processing Record 1 of Set 41 |  liepaja
# Processing Record 2 of Set 41 |  moose factory
# Processing Record 3 of Set 41 |  phuket
# Processing Record 4 of Set 41 |  abu dhabi
# Processing Record 5 of Set 41 |  the valley
# Processing Record 6 of Set 41 |  agirish
# Processing Record 7 of Set 41 |  konin
# Processing Record 8 of Set 41 |  kissidougou
# Processing Record 9 of Set 41 |  mae sot
# Processing Record 10 of Set 41 |  vacha
# Processing Record 11 of Set 41 |  rocha
# Processing Record 12 of Set 41 |  filotion
# Missing City....skipping
# Processing Record 1 of Set 42 |  sokoto
# Processing Record 2 of Set 42 |  guia de isora
# Processing Record 3 of Set 42 |  san quintin
# Processing Record 4 of Set 42 |  lagoa
# Processing Record 5 of Set 42 |  teguise
# Processing Record 6 of Set 42 |  rongcheng
# Processing Record 7 of Set 42 |  tual
# Processing Record 8 of Set 42 |  mutare
# Processing Record 9 of Set 42 |  nanyang
# Processing Record 10 of Set 42 |  muskegon
# Missing City....skipping
# Processing Record 1 of Set 43 |  eldorado
# Processing Record 2 of Set 43 |  valparaiso
# Processing Record 3 of Set 43 |  zhezkazgan
# Processing Record 4 of Set 43 |  leningradskiy
# Processing Record 5 of Set 43 |  lazarev
# Processing Record 6 of Set 43 |  comodoro rivadavia
# Processing Record 7 of Set 43 |  nalut
# Processing Record 8 of Set 43 |  ishigaki
# Processing Record 9 of Set 43 |  yatou
# Processing Record 10 of Set 43 |  poum
# Processing Record 11 of Set 43 |  dong xoai
# Processing Record 12 of Set 43 |  raudeberg
# Processing Record 13 of Set 43 |  shambu
# Processing Record 14 of Set 43 |  pustoshka
# Processing Record 15 of Set 43 |  najran
# Processing Record 16 of Set 43 |  kulhudhuffushi
# Processing Record 17 of Set 43 |  batagay
# Processing Record 18 of Set 43 |  saint-medard-en-jalles
# Processing Record 19 of Set 43 |  san andres
# Processing Record 20 of Set 43 |  pointe michel
# Processing Record 21 of Set 43 |  honjo
# Processing Record 22 of Set 43 |  kayerkan
# Processing Record 23 of Set 43 |  araouane
# Processing Record 24 of Set 43 |  gravdal
# Processing Record 25 of Set 43 |  kasempa
# Processing Record 26 of Set 43 |  klamath falls
# Processing Record 27 of Set 43 |  lalmohan
# Processing Record 28 of Set 43 |  uvat
# Processing Record 29 of Set 43 |  wewak
# Processing Record 30 of Set 43 |  cam ranh
# Processing Record 31 of Set 43 |  kamarion
# Processing Record 32 of Set 43 |  olinda
# Processing Record 33 of Set 43 |  beroroha
# Processing Record 34 of Set 43 |  horki
# Missing City....skipping
# Processing Record 1 of Set 44 |  ostersund
# Processing Record 2 of Set 44 |  varhaug
# Missing City....skipping
# Processing Record 1 of Set 45 |  opuwo
# Missing City....skipping
# Processing Record 1 of Set 46 |  ahipara
# Processing Record 2 of Set 46 |  salinopolis
# Processing Record 3 of Set 46 |  carmo do rio claro
# Processing Record 4 of Set 46 |  vila franca do campo
# Processing Record 5 of Set 46 |  klaksvik
# Processing Record 6 of Set 46 |  nara
# Processing Record 7 of Set 46 |  taldan
# Processing Record 8 of Set 46 |  mount gambier
# Processing Record 9 of Set 46 |  vagur
# Processing Record 10 of Set 46 |  arlit
# Missing City....skipping
# Processing Record 1 of Set 47 |  aykhal
# Processing Record 2 of Set 47 |  narasannapeta
# Processing Record 3 of Set 47 |  sibu
# Processing Record 4 of Set 47 |  komsomolskiy
# Processing Record 5 of Set 47 |  vega de alatorre
# Processing Record 6 of Set 47 |  radcliff
# Processing Record 7 of Set 47 |  hita
# Processing Record 8 of Set 47 |  bathsheba
# Processing Record 9 of Set 47 |  oksbol
# Processing Record 10 of Set 47 |  carstairs
# Processing Record 11 of Set 47 |  bayan
# Processing Record 12 of Set 47 |  kobelyaky
# Processing Record 13 of Set 47 |  nehe
# Processing Record 14 of Set 47 |  westport
# Processing Record 15 of Set 47 |  simpang
# Processing Record 16 of Set 47 |  outjo
# Processing Record 17 of Set 47 |  tomatlan
# Processing Record 18 of Set 47 |  los llanos de aridane
# Processing Record 19 of Set 47 |  pyatigorskiy
# Processing Record 20 of Set 47 |  beinamar
# Processing Record 21 of Set 47 |  isangel
# Processing Record 22 of Set 47 |  cascais
# Processing Record 23 of Set 47 |  chara
# Processing Record 24 of Set 47 |  lugazi
# Processing Record 25 of Set 47 |  khasan
# Processing Record 26 of Set 47 |  touros
# Processing Record 27 of Set 47 |  la cruz
# Processing Record 28 of Set 47 |  basoko
# Missing City....skipping
# Processing Record 1 of Set 48 |  gao
# Processing Record 2 of Set 48 |  odemira
# Processing Record 3 of Set 48 |  roebourne
# Processing Record 4 of Set 48 |  misratah
# Missing City....skipping
# Missing City....skipping
# Processing Record 1 of Set 50 |  port-gentil
# Processing Record 2 of Set 50 |  abu samrah
# Processing Record 3 of Set 50 |  prado
# Missing City....skipping
# Missing City....skipping
# Missing City....skipping
# Processing Record 1 of Set 53 |  port hedland
# Processing Record 2 of Set 53 |  petropavlovsk-kamchatskiy
# Processing Record 3 of Set 53 |  umm lajj
# Processing Record 4 of Set 53 |  sanquhar
# Processing Record 5 of Set 53 |  bafoulabe
# Processing Record 6 of Set 53 |  hat yai
# Processing Record 7 of Set 53 |  veraval
# Processing Record 8 of Set 53 |  san cristobal
# Processing Record 9 of Set 53 |  rayong
# Processing Record 10 of Set 53 |  dobris
# Processing Record 11 of Set 53 |  port macquarie
# Processing Record 12 of Set 53 |  middelburg
# Missing City....skipping
# Processing Record 1 of Set 54 |  inhambane
# Processing Record 2 of Set 54 |  yulara
# Processing Record 3 of Set 54 |  saint anthony
# Processing Record 4 of Set 54 |  lebedinyy
# Processing Record 5 of Set 54 |  northam
# Processing Record 6 of Set 54 |  clyde river
# Processing Record 7 of Set 54 |  iwaki
# Processing Record 8 of Set 54 |  ancud
# Processing Record 9 of Set 54 |  mnogovershinnyy
# Missing City....skipping
# Processing Record 1 of Set 55 |  sarishabari
# Processing Record 2 of Set 55 |  kharp
# Processing Record 3 of Set 55 |  ust-tsilma
# Processing Record 4 of Set 55 |  henties bay
# Processing Record 5 of Set 55 |  tokur
# Processing Record 6 of Set 55 |  sinnamary
# Processing Record 7 of Set 55 |  punta cardon
# Processing Record 8 of Set 55 |  kawai
# Processing Record 9 of Set 55 |  genhe
# Processing Record 10 of Set 55 |  burnie
# Processing Record 11 of Set 55 |  udachnyy
# Processing Record 12 of Set 55 |  saint marys
# Processing Record 13 of Set 55 |  urucara
# Processing Record 14 of Set 55 |  hualmay
# Processing Record 15 of Set 55 |  nurota
# Processing Record 16 of Set 55 |  tura
# Processing Record 17 of Set 55 |  ketchikan
# Processing Record 18 of Set 55 |  gat
# Processing Record 19 of Set 55 |  lukovetskiy
# Processing Record 20 of Set 55 |  kaeo
# Processing Record 21 of Set 55 |  broken hill
# Processing Record 22 of Set 55 |  kloulklubed
# Processing Record 23 of Set 55 |  praya
# Processing Record 24 of Set 55 |  gorontalo
# Processing Record 25 of Set 55 |  pouebo
# Processing Record 26 of Set 55 |  maua
# Processing Record 27 of Set 55 |  ondjiva
# Processing Record 28 of Set 55 |  meadow lake
# Processing Record 29 of Set 55 |  tabas
# Processing Record 30 of Set 55 |  voh
# Processing Record 31 of Set 55 |  velikiy ustyug
# Processing Record 32 of Set 55 |  ahuimanu
# Missing City....skipping
# Processing Record 1 of Set 56 |  ribnitz-damgarten
# Processing Record 2 of Set 56 |  kununurra
# Processing Record 3 of Set 56 |  linxia
# Processing Record 4 of Set 56 |  yaan
# Processing Record 5 of Set 56 |  andros town
# Processing Record 6 of Set 56 |  gornopravdinsk
# Processing Record 7 of Set 56 |  cap malheureux
# Processing Record 8 of Set 56 |  cabedelo
# Processing Record 9 of Set 56 |  bakchar
# Processing Record 10 of Set 56 |  monastyrshchina
# Processing Record 11 of Set 56 |  mildura
# Processing Record 12 of Set 56 |  tuy hoa
# Processing Record 13 of Set 56 |  yartsevo
# Processing Record 14 of Set 56 |  yate
# Processing Record 15 of Set 56 |  antalaha
# Processing Record 16 of Set 56 |  pachino
# Processing Record 17 of Set 56 |  socorro
# Processing Record 18 of Set 56 |  zhaodong
# Processing Record 19 of Set 56 |  svidnik
# Processing Record 20 of Set 56 |  carauari
# Processing Record 21 of Set 56 |  bustamante
# Missing City....skipping
# Processing Record 1 of Set 57 |  ilfracombe
# Processing Record 2 of Set 57 |  golden
# Missing City....skipping
# Processing Record 1 of Set 58 |  vilani
# Missing City....skipping
# Processing Record 1 of Set 59 |  catalina
# Processing Record 2 of Set 59 |  yumen
# Processing Record 3 of Set 59 |  baculin
# Processing Record 4 of Set 59 |  atar
# Processing Record 5 of Set 59 |  semey
# Processing Record 6 of Set 59 |  south lake tahoe
# Processing Record 7 of Set 59 |  bosaso
# Processing Record 8 of Set 59 |  mogadishu
# Processing Record 9 of Set 59 |  mogapinyana
# Processing Record 10 of Set 59 |  bela
# Processing Record 11 of Set 59 |  gazojak
# Processing Record 12 of Set 59 |  changchun
# Missing City....skipping
# Missing City....skipping
# Processing Record 1 of Set 61 |  lewisporte
# Processing Record 2 of Set 61 |  bandarbeyla
# Processing Record 3 of Set 61 |  kargasok
# Processing Record 4 of Set 61 |  tucuman
# Processing Record 5 of Set 61 |  rupert
# Processing Record 6 of Set 61 |  mala vyska
# Processing Record 7 of Set 61 |  egvekinot
# Processing Record 8 of Set 61 |  tiarei
# Processing Record 9 of Set 61 |  mazamari
# Processing Record 10 of Set 61 |  progreso
# Processing Record 11 of Set 61 |  krasnoturansk
# Processing Record 12 of Set 61 |  inuvik
# Processing Record 13 of Set 61 |  kenai
# Processing Record 14 of Set 61 |  peniche
# Processing Record 15 of Set 61 |  muros
# Processing Record 16 of Set 61 |  anloga
# Processing Record 17 of Set 61 |  ginda
# Processing Record 18 of Set 61 |  ossora
# Processing Record 19 of Set 61 |  luanda
# Processing Record 20 of Set 61 |  kitob
# Processing Record 21 of Set 61 |  barcelos
# Processing Record 22 of Set 61 |  elban
# Missing City....skipping
# Processing Record 1 of Set 62 |  mehamn
# Processing Record 2 of Set 62 |  hayden
# Processing Record 3 of Set 62 |  niigata
# Processing Record 4 of Set 62 |  severo-kurilsk
# Processing Record 5 of Set 62 |  baymak
# Processing Record 6 of Set 62 |  narrabri
# Processing Record 7 of Set 62 |  yamada
# Processing Record 8 of Set 62 |  sabang
# Processing Record 9 of Set 62 |  belmonte
# Processing Record 10 of Set 62 |  college
# Processing Record 11 of Set 62 |  sirohi
# Processing Record 12 of Set 62 |  kalmunai
# Processing Record 13 of Set 62 |  menongue
# Processing Record 14 of Set 62 |  pokhara
#  Extraction Complelte

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather_df = pd.DataFrame(city_weather)
city_weather_df.count()
# Out:
# City          555
# Cloudiness    555
# Country       555
# Date          555
# Humidity      555
# Lat           555
# Lng           555
# Max_Temp      555
# Wind_Speed    555
# dtype: int64

# %%
city_weather_df.columns
# Out:
# Index(['City', 'Cloudiness', 'Country', 'Date', 'Humidity', 'Lat', 'Lng',
#        'Max_Temp', 'Wind_Speed'],
#       dtype='object')

# %%
# Create a csv file with city weather 

city_weather_df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
plt.scatter(city_weather_df.Lat,city_weather_df.Max_Temp,marker='o', edgecolors='black')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs. Max Temperature ({current_date})")
plt.grid(True)
#plt.fig.canvas.draw_idle()
plt.savefig('output_data/lat_temp_plot.png')
plt.show()

# %% [markdown]
# ### Latitude vs. Humidity Plot

# %%
plt.scatter(city_weather_df.Lat,city_weather_df.Humidity,marker='o', edgecolors='black')

plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity ({current_date})")
plt.grid()
plt.savefig('output_data/Humidity_plot.png')
plt.show()

# %% [markdown]
# ### Latitude vs. Cloudiness

# %%
plt.scatter(city_weather_df.Lat,city_weather_df.Cloudiness,marker='o', edgecolors='black')

plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs. Cloudiness ({current_date})")
plt.grid()
plt.savefig('output_data/Cloudiness_plot.png')
plt.show()

# %% [markdown]
# ### Latitude vs. Wind Speed

# %%
plt.scatter(city_weather_df.Lat,city_weather_df.Wind_Speed,marker='o', edgecolors='black')

plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title(f"City Latitude vs. Wind Speed ({current_date})")
plt.grid()
plt.savefig('output_data/Wind_Speed_plot.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
